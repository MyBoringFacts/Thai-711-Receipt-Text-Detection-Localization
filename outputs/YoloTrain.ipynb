# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
model = YOLO("yolo11m.pt")
# Out:
# ...
# 100%|██████████| 38.8M/38.8M [00:00<00:00, 224MB/s]

# %%
results = model.train(data="/teamspace/studios/this_studio/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# results = model("istockphoto-914023158-612x612.jpg",show = True, save = True)
# results.show()

# %%
model.save("best_model.pt")

# %%
from ultralytics import YOLO

# Load the trained model (adjust the path to your saved model)
model = YOLO("best_model.pt")
results = model.predict(source=r"Image.jpg", imgsz=640, conf=0.25)

# If you expect a single result:
results[0].show()

# Or loop through all results:
for result in results:
    result.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from ultralytics import YOLO
#       3 # Load the trained model (adjust the path to your saved model)
# ----> 4 model = YOLO("best_model.pt")
#       5 results = model.predict(source=r"Image.jpg", imgsz=640, conf=0.25)
#       7 # If you expect a single result:
#
# File c:\Users\TDH\VIIIIIV\MVIIXXIV\2024\Assumption University 3y sem2\CSX_4201_Ai_Concepts\PROJECT\ai_concept_env\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# ...
